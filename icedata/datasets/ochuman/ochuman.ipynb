# %%
from icevision.all import *
import icedata

_ = icedata.ochuman.load_data()
# Out:
# INFO     -
#     MANUALLY download AND unzip the dataset from https://cg.cs.tsinghua.edu.cn/dataset/form.html?dataset=ochuman.
#     You will need the path to the `ochuman.json` annotations file and the `images` directory.
#      | icedata.datasets.ochuman.data:load_data:7

# %%
parser = icedata.ochuman.parser("./icedata/datasets/ochuman/sample_data/annotations/ochuman.json",
                                "./icedata/datasets/ochuman/sample_data/images")

# %%
train_records, valid_records = parser.parse(data_splitter=RandomSplitter([0.8, 0.2]), cache_filepath=None)
# Out:
# ...
# INFO     - Autofixing records | icevision.parsers.parser:parse:126

# %%
show_records(train_records[:4], ncols=2)
